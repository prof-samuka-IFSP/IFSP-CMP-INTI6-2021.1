# %% [markdown]
# **INTL6: Inteligência Artificial (2021.1)** <br/>
# IFSP Campinas
#
# Prof. Dr. Samuel Botter Martins <br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h1>Análise Exploratória de Dados</h1><hr/>

# %% [markdown]
# A **Análise Exploratória de Dados** refere-se ao processo de investigação de dados (de um problema) para a descoberta de _insights_, padrões, anomalias, testar hipóteses e checar suposições com a ajuda de técnicas e conceitos estatísticos e representações visuais/gráficas.

# %% [markdown]
# <h2>1. Dataset</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.

# %% [markdown]
# O dataset utilizado neste notebook já foi _pré-processado_ anteriormente. Para mais informações, cheque os vídeos mostrados do curso ["Pandas Essencial" no YouTube](https://www.youtube.com/playlist?list=PL3ZslI15yo2pfkf7EGNR14xTwe-wZ2bNX), onde realizamos tal preprocessamento.

# %% [markdown]
# ### 1.1. Importando o Dataset

# %%
df = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ### 1.2. Informações básicas do Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  object
#  1   DATA FINAL                     103392 non-null  object
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %% [markdown]
# <br/>
#
# O dataset possui **103392** registros/observações/linhas e **20** atributos/variáveis/colunas.
# Não há nenhum valor null nas colunas (uma checagem mais rigorosa foi feita no curso ["Pandas Essencial"](https://www.youtube.com/playlist?list=PL3ZslI15yo2pfkf7EGNR14xTwe-wZ2bNX)).

# %% [markdown]
# <h2>2. Análise Exploratória de Dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
df['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
df['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
gasolina_sp_2018 = df.query('ESTADO == "SAO PAULO" and PRODUTO == "GASOLINA COMUM" and ANO == 2018').reset_index(drop=True)
gasolina_sp_2018.head()
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 0   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 1   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 2   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 3   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 4   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          1641              R$/l                3.988
# 1                          1648              R$/l                4.002
# 2                          1648              R$/l                4.006
# 3                          1644              R$/l                4.019
# 4                          1646              R$/l                4.004
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.156                 3.499                 4.599
# ...

# %%
gasolina_sp_2018.shape
# Out:
# (52, 20)

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
# computa estatísticas descritivas para toda a base
gasolina_sp_2018.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# ...

# %%
gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    52.000000
# mean      4.202769
# std       0.180672
# min       3.970000
# 25%       4.008000
# 50%       4.202000
# 75%       4.336250
# max       4.512000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
stats
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# #### **Tendência Central dos Preços**

# %%
print(f"O preço médio da Gasolina Comum no Estado de São Paulo em 2018 foi de {stats.loc['mean', 'PREÇO MÉDIO REVENDA']:.2f} +- {stats.loc['std', 'PREÇO MÉDIO REVENDA']:.2f}")
print(f"A mediana dos preços da Gasolina Comum no Estado de São Paulo em 2018 foi de {stats.loc['50%', 'PREÇO MÉDIO REVENDA']:.2f}")
# Out:
# O preço médio da Gasolina Comum no Estado de São Paulo em 2018 foi de 4.20 +- 0.18
# A mediana dos preços da Gasolina Comum no Estado de São Paulo em 2018 foi de 4.20

# %%
plt.figure(figsize=(6, 6))

sns.barplot(data=gasolina_sp_2018, y='PREÇO MÉDIO REVENDA', ci='sd')
plt.ylabel('Preço Médio (R$)')

# plt.yticks([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5])
plt.yticks(np.arange(0, 5.01, 0.25))
# plt.yticks(np.arange(0, gasolina_sp_2018['PREÇO MÉDIO REVENDA'].max() + 0.01, 0.25))
plt.title('Gasolina Comum no Estado de SP em 2018', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Gasolina Comum no Estado de SP em 2018')

# %%
plt.figure(figsize=(6, 6))

ax = sns.barplot(data=gasolina_sp_2018, y='PREÇO MÉDIO REVENDA', ci='sd')
plt.ylabel('Preço Médio (R$)')
plt.yticks(np.arange(0, 5.01, 0.25))
plt.title('Gasolina Comum no Estado de SP em 2018', fontsize=18)

for bar in ax.patches:
    preco_medio = bar.get_height()
    x = bar.get_x() + bar.get_width()
    y = bar.get_height()
    
    ax.annotate(f'R$ {preco_medio:.2f}',
               xy=(x, y),
               xytext=(0, 3),
               textcoords="offset points",
                ha="center", va="bottom")

# %% [markdown]
# ### **Variabilidade**

# %% [markdown]
# #### Histograma com número de bins padrão:

# %%
sns.histplot(data=gasolina_sp_2018, x='PREÇO MÉDIO REVENDA')
plt.xlabel('Preço Médio (R$)')
plt.ylabel('Contagem')
plt.title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
# Out:
# Text(0.5, 1.0, 'Histograma dos Preços da Gasolina do Estado de SP em 2018')

# %% [markdown]
# #### Alterando o **número de bins** do Histograma.

# %%
sns.histplot(data=gasolina_sp_2018, x='PREÇO MÉDIO REVENDA', bins=20)
plt.xlabel('Preço Médio (R$)')
plt.ylabel('Contagem')
plt.title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
# Out:
# Text(0.5, 1.0, 'Histograma dos Preços da Gasolina do Estado de SP em 2018')

# %%
sns.histplot(data=gasolina_sp_2018, x='PREÇO MÉDIO REVENDA', bins=20, kde=True)
plt.xlabel('Preço Médio (R$)')
plt.ylabel('Contagem')
plt.title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
# Out:
# Text(0.5, 1.0, 'Histograma dos Preços da Gasolina do Estado de SP em 2018')

# %% [markdown]
# #### Checando a variabilidade usando **BoxPlots**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=gasolina_sp_2018, x='PREÇO MÉDIO REVENDA')
plt.xticks(np.arange(3.5, 4.7, 0.05), rotation=45)
plt.title('Boxplot da Gasolina do Estado de SP em 2018')
# Out:
# Text(0.5, 1.0, 'Boxplot da Gasolina do Estado de SP em 2018')

# %% [markdown]
# #### Checando a variabilidade usando **Violin Plot**

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=gasolina_sp_2018, x='PREÇO MÉDIO REVENDA')
plt.xticks(np.arange(3.5, 4.7, 0.05), rotation=45)
plt.title('Boxplot da Gasolina do Estado de SP em 2018')
# Out:
# Text(0.5, 1.0, 'Boxplot da Gasolina do Estado de SP em 2018')

# %% [markdown]
# ### 2.2 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
gasolina_etanol_sp_2018 = df.query('ESTADO == "SAO PAULO" and ANO == 2018 and PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"]')
gasolina_etanol_sp_2018
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
gasolina_etanol_sp_2018['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM'], dtype=object)

# %% [markdown]
# #### Computando as estatísticas descritivas

# %%
gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512

# %% [markdown]
# #### Gráfico de Barras

# %%
plt.figure(figsize=(6, 6))

sns.barplot(data=gasolina_etanol_sp_2018, x='PRODUTO', y='PREÇO MÉDIO REVENDA', ci='sd')
plt.ylabel('Preço Médio (R$)')
plt.yticks(np.arange(0, 5.01, 0.25))
plt.title('Etanol e Gasolina Comum no Estado de SP em 2018', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Etanol e Gasolina Comum no Estado de SP em 2018')

# %%
plt.figure(figsize=(6, 6))

ax = sns.barplot(data=gasolina_etanol_sp_2018, x='PRODUTO', y='PREÇO MÉDIO REVENDA', ci='sd')
plt.ylabel('Preço Médio (R$)')
plt.yticks(np.arange(0, 5.01, 0.25))
plt.title('Etanol e Gasolina Comum no Estado de SP em 2018', fontsize=16)

for bar in ax.patches:
    preco_medio = bar.get_height()
    x = bar.get_x() + bar.get_width()
    y = bar.get_height()
    
    ax.annotate(f'R$ {preco_medio:.2f}',
               xy=(x, y),
               xytext=(0, 3),
               textcoords="offset points",
               ha="center", va="bottom")

# %% [markdown]
# #### Histogramas

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=gasolina_etanol_sp_2018, x='PREÇO MÉDIO REVENDA', bins=20, hue='PRODUTO')
# Out:
# <AxesSubplot:xlabel='PREÇO MÉDIO REVENDA', ylabel='Count'>

# %% [markdown]
# #### BoxPlot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=gasolina_etanol_sp_2018, x='PRODUTO', y='PREÇO MÉDIO REVENDA')
plt.title('Boxplot ...')
# Out:
# Text(0.5, 1.0, 'Boxplot ...')

# %% [markdown]
# #### Violin Plot

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=gasolina_etanol_sp_2018, x='PREÇO MÉDIO REVENDA', y='PRODUTO')
plt.title('Violion Plot ...')
# plt.xticks(np.arange(0.0, 5.01, 0.25))
plt.xticks(np.arange(gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].min(),
                     gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].max() + 0.01, 0.25))
display()

# %% [markdown]
# ### 2.3 Como os preços da Gasolina Comum e Etanol variaram no estado de SP ao longo dos anos?

# %%
gasolina_etanol_sp = df.query('ESTADO == "SAO PAULO" and PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"]')
gasolina_etanol_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 103058   2019-06-09  2019-06-15  SUDESTE  SAO PAULO    GASOLINA COMUM
# 103123   2019-06-16  2019-06-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103204   2019-06-16  2019-06-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 103269   2019-06-23  2019-06-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
stats = gasolina_etanol_sp.groupby(by=['ANO', 'PRODUTO'])['PREÇO MÉDIO REVENDA'].describe()
stats
# Out:
#                        count      mean       std    min      25%     50%  \
# ANO  PRODUTO
# 2004 ETANOL HIDRATADO   34.0  1.049059  0.157977  0.766  0.90475  1.0325
#      GASOLINA COMUM     34.0  2.047294  0.087135  1.888  2.03000  2.0340
# 2005 ETANOL HIDRATADO   50.0  1.182500  0.112241  0.978  1.07075  1.2170
#      GASOLINA COMUM     50.0  2.232900  0.087034  2.144  2.16175  2.1910
# 2006 ETANOL HIDRATADO   53.0  1.419623  0.189749  1.211  1.25800  1.3550
#      GASOLINA COMUM     53.0  2.442585  0.030641  2.383  2.42100  2.4450
# 2007 ETANOL HIDRATADO   52.0  1.272212  0.146878  1.063  1.11225  1.2960
#      GASOLINA COMUM     52.0  2.413865  0.024343  2.376  2.39275  2.4165
# 2008 ETANOL HIDRATADO   52.0  1.273769  0.028608  1.228  1.24875  1.2700
#      GASOLINA COMUM     52.0  2.402788  0.006393  2.393  2.39700  2.4020
# 2009 ETANOL HIDRATADO   50.0  1.329040  0.144401  1.134  1.22375  1.3000
#      GASOLINA COMUM     50.0  2.403000  0.027974  2.353  2.38100  2.4020
# ...

# %% [markdown]
# #### Lineplot

# %%
plt.figure(figsize=(20,16))
sns.lineplot(data=gasolina_etanol_sp, x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci='sd')
plt.xticks(range(2004, 2020))
plt.yticks(np.arange(0.0, 4.501, 0.1))
plt.grid()

# %% [markdown]
# #### Boxplots

# %%
plt.figure(figsize=(18,12))
sns.boxplot(data=gasolina_etanol_sp, x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', dodge=False, )
plt.grid()

# %% [markdown]
# #### Violin Plot

# %%
plt.figure(figsize=(18,12))
sns.violinplot(data=gasolina_etanol_sp, x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', dodge=False)
plt.grid()

# %%
plt.figure(figsize=(10, 10))
sns.violinplot(data=gasolina_etanol_sp.query('ANO == 2011 and PRODUTO == "GASOLINA COMUM"'), x='PREÇO MÉDIO REVENDA', color='orange')
# Out:
# <AxesSubplot:xlabel='PREÇO MÉDIO REVENDA'>

# %% [markdown]
# ### 2.4 Há correlação entre os preços da Gasolina Comum e do Etanol do estado de São Paulo de 2018?

# %%
gasolina_etanol_sp_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92238                          1664              R$/l                2.833
# 92319                          1641              R$/l                3.988
# 92384                          1661              R$/l                2.868
# 92465                          1648              R$/l                4.002
# 92529                          1662              R$/l                2.874
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### 2.5 Como os preços da Gasolina Comum e Etanol variaram no estado de SP ao longo dos anos e meses?

# %% [markdown]
# #### Correlação entre os Preços da Gasolina e Etanol no Estado de SP

# %% [markdown]
# ### 2.6 Preços dos Combustíveis por Região ao longo dos anos e meses?

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# juntando os meses e anos em uma data só
df['ANO-MÊS'] = pd.to_datetime({
    'day': 1,
    'month': df['MÊS'],
    'year': df['ANO']
})

# %%
df['MÊS-ANO'] = df.apply(lambda linha: f'{linha["MÊS"]}-{linha["ANO"]}', axis=1)
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# #### UMA ALTERNATIVA

# %%
df['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
df['REGIÃO'].unique()
# Out:
# array(['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'],
#       dtype=object)

# %%
plt.figure(figsize=(18,12))
sns.lineplot(data=df.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None)
# Out:
# <AxesSubplot:xlabel='ANO', ylabel='PREÇO MÉDIO REVENDA'>

# %%
# 'ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=df.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DO ETANOL AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GASOLINA COMUM"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DA GASOLINA COMUM AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GLP"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DO GLP AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GNV"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DO GNV AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "ÓLEO DIESEL"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "ÓLEO DIESEL S10"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[2, 1], )
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL S10 AO LONGO DOS ANOS')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ÓLEO DIESEL S10 AO LONGO DOS ANOS')

# %%
# 'ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=df.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DO ETANOL AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GASOLINA COMUM"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DA GASOLINA COMUM AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GLP"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DO GLP AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GNV"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DO GNV AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "ÓLEO DIESEL"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "ÓLEO DIESEL S10"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[2, 1], )
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL S10 AO LONGO DOS ANOS')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ÓLEO DIESEL S10 AO LONGO DOS ANOS')

# %%
# 'ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=df.query('PRODUTO == "ETANOL HIDRATADO"'), x='MÊS-ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DO ETANOL AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GASOLINA COMUM"'), x='MÊS-ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DA GASOLINA COMUM AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GLP"'), x='MÊS-ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DO GLP AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "GNV"'), x='MÊS-ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DO GNV AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "ÓLEO DIESEL"'), x='MÊS-ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL AO LONGO DOS ANOS')

sns.lineplot(data=df.query('PRODUTO == "ÓLEO DIESEL S10"'), x='MÊS-ANO', y='PREÇO MÉDIO REVENDA', hue='REGIÃO',
             hue_order=['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'], ci=None, ax=axes[2, 1], )
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL S10 AO LONGO DOS ANOS')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ÓLEO DIESEL S10 AO LONGO DOS ANOS')

# %% [markdown]
# No geral, a região **Norte** é a que apresenta os maiores preços de combustíveis do país.

# %% [markdown]
# #### OUTRA ALTERNATIVA

# %%
df['REGIÃO'].unique()
# Out:
# array(['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'],
#       dtype=object)

# %%
# 'ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=df.query('REGIÃO == "NORTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO NORTE AO LONGO DOS ANOS')


sns.lineplot(data=df.query('REGIÃO == "NORDESTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO NORDESTE AO LONGO DOS ANOS')


sns.lineplot(data=df.query('REGIÃO == "CENTRO OESTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO CENTRO OESTE AO LONGO DOS ANOS')


sns.lineplot(data=df.query('REGIÃO == "SUDESTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO SUDESTE AO LONGO DOS ANOS')


sns.lineplot(data=df.query('REGIÃO == "SUL"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO SUL AO LONGO DOS ANOS')
# Out:
# Text(0.5, 1.0, 'PREÇO DOS COMBUSTÍVEIS DA REGIÃO SUL AO LONGO DOS ANOS')

# %% [markdown]
# Como o preço do GLP é muito discrepante do preço dos outros combustíveis, nossa análise fica totalmente prejudicada. <br/>
# Podemos ignorar o GLP neste momento e comparar os preços entre os outros combustíveis.

# %%
df_viz = df.query('PRODUTO != "GLP"')

# %%
# 'ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'
fig, axes = plt.subplots(3, 2, figsize=(30, 18), sharey=True)

sns.lineplot(data=df_viz.query('REGIÃO == "NORTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO NORTE AO LONGO DOS ANOS')


sns.lineplot(data=df_viz.query('REGIÃO == "NORDESTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO NORDESTE AO LONGO DOS ANOS')


sns.lineplot(data=df_viz.query('REGIÃO == "CENTRO OESTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO CENTRO OESTE AO LONGO DOS ANOS')


sns.lineplot(data=df_viz.query('REGIÃO == "SUDESTE"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO SUDESTE AO LONGO DOS ANOS')


sns.lineplot(data=df_viz.query('REGIÃO == "SUL"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO',
             hue_order=['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10'], ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DOS COMBUSTÍVEIS DA REGIÃO SUL AO LONGO DOS ANOS')
# Out:
# Text(0.5, 1.0, 'PREÇO DOS COMBUSTÍVEIS DA REGIÃO SUL AO LONGO DOS ANOS')

# %% [markdown]
# ### 2.7 Comportamento dos Preços dos Combustíveis dos Estados do Norte?

# %%
df_norte = df.query('REGIÃO == "NORTE"')
df_norte
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO     ESTADO           PRODUTO  \
# 13       2004-05-09  2004-05-15  NORTE       ACRE  ETANOL HIDRATADO
# 14       2004-05-09  2004-05-15  NORTE      AMAPA  ETANOL HIDRATADO
# 15       2004-05-09  2004-05-15  NORTE   AMAZONAS  ETANOL HIDRATADO
# 16       2004-05-09  2004-05-15  NORTE       PARA  ETANOL HIDRATADO
# 17       2004-05-09  2004-05-15  NORTE   RONDONIA  ETANOL HIDRATADO
# ...             ...         ...    ...        ...               ...
# 103356   2019-06-23  2019-06-29  NORTE   AMAZONAS               GLP
# 103366   2019-06-23  2019-06-29  NORTE       PARA               GLP
# 103374   2019-06-23  2019-06-29  NORTE   RONDONIA               GLP
# 103375   2019-06-23  2019-06-29  NORTE    RORAIMA               GLP
# 103379   2019-06-23  2019-06-29  NORTE  TOCANTINS               GLP
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_norte.query('PRODUTO == "GASOLINA COMUM"'), x='ESTADO', y='PREÇO MÉDIO REVENDA', ci='sd')
# Out:
# <AxesSubplot:xlabel='ESTADO', ylabel='PREÇO MÉDIO REVENDA'>

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df_norte.query('PRODUTO == "GASOLINA COMUM"'), x='ESTADO', y='PREÇO MÉDIO REVENDA', ci='sd')
# Out:
# <AxesSubplot:xlabel='ESTADO', ylabel='PREÇO MÉDIO REVENDA'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_norte.query('PRODUTO == "ETANOL HIDRATADO"'), x='ESTADO', y='PREÇO MÉDIO REVENDA', ci='sd')
# Out:
# <AxesSubplot:xlabel='ESTADO', ylabel='PREÇO MÉDIO REVENDA'>

# %% [markdown]
# Na média, o estado do **ACRE** apresentou **os preços mais caros** para a _Gasolina Comum_ e _Etanol_ considerando os anos de 2004 a 2018

# %% [markdown]
# ##### **ANALISANDO OS PREÇOS ANO A ANO**

# %%
plt.figure(figsize=(20, 6))
sns.barplot(data=df_norte.query('PRODUTO == "GASOLINA COMUM"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='ESTADO', ci='sd')
# Out:
# <AxesSubplot:xlabel='ANO', ylabel='PREÇO MÉDIO REVENDA'>

# %%
plt.figure(figsize=(20, 6))
sns.barplot(data=df_norte.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='ESTADO', ci='sd')
# Out:
# <AxesSubplot:xlabel='ANO', ylabel='PREÇO MÉDIO REVENDA'>

# %% [markdown]
# ### 2.8 Há correlação entre os Preços de Distribuição e o Preço de Revenda dos combustíveis?

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
df_precos = df[['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
df_precos
# Out:
#         PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# 0                     1.288                     0.825
# 1                     1.162                     0.763
# 2                     1.389                     0.970
# 3                     1.262                     0.830
# 4                     1.181                     0.941
# ...                     ...                       ...
# 103387                3.574                     2.756
# 103388                3.401                     2.451
# 103389                2.912                     1.998
# 103390                3.020                     2.374
# 103391                3.697                     2.518
#
# [103392 rows x 2 columns]

# %%
df_precos.corr()
# Out:
#                           PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# PREÇO MÉDIO REVENDA                  1.000000                  0.994852
# PREÇO MÉDIO DISTRIBUIÇÃO             0.994852                  1.000000

# %%
sns.lmplot(data=df_precos, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA', height=10)

# %%
plt.figure(figsize=(20,20))
sns.regplot(data=df_precos, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA')
# Out:
# <AxesSubplot:xlabel='PREÇO MÉDIO DISTRIBUIÇÃO', ylabel='PREÇO MÉDIO REVENDA'>

# %%
sns.jointplot(data=df_precos, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA', height=10)

# %%
sns.jointplot(data=df_precos, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA', height=10, kind='hex')

# %%
selecao = df_precos["PREÇO MÉDIO DISTRIBUIÇÃO"] <= 10
df_precos_distribuicao_menor_que_10 = df_precos[selecao]
df_precos_distribuicao_menor_que_10
# Out:
#         PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# 0                     1.288                     0.825
# 1                     1.162                     0.763
# 2                     1.389                     0.970
# 3                     1.262                     0.830
# 4                     1.181                     0.941
# ...                     ...                       ...
# 103387                3.574                     2.756
# 103388                3.401                     2.451
# 103389                2.912                     1.998
# 103390                3.020                     2.374
# 103391                3.697                     2.518
#
# [83077 rows x 2 columns]

# %%
df.query('PRODUTO != "GLP"').shape
# Out:
# (83077, 22)

# %%
sns.jointplot(data=df_precos_distribuicao_menor_que_10, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA', height=10)

# %%
sns.jointplot(data=df_precos_distribuicao_menor_que_10, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA', height=10, kind='hex')
